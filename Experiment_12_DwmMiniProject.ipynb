# %% [markdown]
# <a href="https://colab.research.google.com/github/hackergod00001/NLP-Video-Summarization-with-Watson-and-GPT/blob/master/Experiment_12_DwmMiniProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Youtube Video Transcript Summarization with Hugging Face Transformers**

# %%
# !pip install -q transformers
# Out:
#      |████████████████████████████████| 2.9 MB 30.5 MB/s
#      |████████████████████████████████| 895 kB 49.3 MB/s
#      |████████████████████████████████| 596 kB 58.0 MB/s
#      |████████████████████████████████| 3.3 MB 72.2 MB/s
#      |████████████████████████████████| 56 kB 5.3 MB/s

# %%
# !pip install -q youtube_transcript_api

# %%
from transformers import pipeline
from youtube_transcript_api import YouTubeTranscriptApi

# %%
youtube_video = "https://www.youtube.com/watch?v=Iw363WNPReQ"

# %%
video_id = youtube_video.split("=")[1]

# %%
video_id
# Out:
# 'Iw363WNPReQ'

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(video_id)

# %%
YouTubeTranscriptApi.get_transcript(video_id)
transcript = YouTubeTranscriptApi.get_transcript(video_id)

# %%
transcript[0:5]
# Out:
# [{'duration': 1.96,
#   'start': 10.86,
#   'text': 'Jonathan Berent: Thank you so much for joining\nus today, Sadhguru.'},
#  {'duration': 4.34,
#   'start': 12.82,
#   'text': 'I think the audience is very interested in\nwhat you have to say.'},
#  {'duration': 4.71,
#   'start': 17.16,
#   'text': 'I guess to start, they define inclusive consciousness.'},
#  {'duration': 2.19,
#   'start': 21.87,
#   'text': 'I’d love to hear your thoughts on–'},
#  {'duration': 1.59,
#   'start': 24.06,
#   'text': 'Sadhguru: They did not define it.'}]

# %%
result = ""
for i in transcript:
    result += ' ' + i['text']
#print(result)
print(len(result))
# Out:
# 49625

# %%
summarizer = pipeline('summarization')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 (https://huggingface.co/sshleifer/distilbart-cnn-12-6)
# Downloading:   0%|          | 0.00/1.76k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.14G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]

# %%
num_iters = int(len(result)/1000)
summarized_text = []
for i in range(0, num_iters + 1):
  start = 0
  start = i * 1000
  end = (i + 1) * 1000
  print("input text \n" + result[start:end])
  out = summarizer(result[start:end])
  out = out[0]
  out = out['summary_text']
  print("Summarized text\n"+out)
  summarized_text.append(out)
# Out:
# input text
#  Jonathan Berent: Thank you so much for joining
# us today, Sadhguru. I think the audience is very interested in
# what you have to say. I guess to start, they define inclusive consciousness. I’d love to hear your thoughts on– Sadhguru: They did not define it. Jonathan Berent: They did not, OK. Well I was just going to ask you what’s
# missing. So you can start. Sadhguru: With all due respect, they spoke
# about intent, right intent. They spoke about the right kind of thoughts,
# emotions, attitudes, and to some extent actions. There is no consciousness in this. If we are understanding that the way we think,
# feel, and act is of a consciousness, no. It is like we are mistaking a plant. We are mistaking the flower for the soil. We are mistaking expressions for the source. This is something that’s happening everywhere,
# not just here. People think by changing attitudes, their
# consciousness will change. No. By changing attitudes, certain actions will
# ...

# %%
len(str(summarized_text))
# Out:
# 17052

# %%
str(summarized_text)
# Out:
# '[" Jonathan Berent: Sadhguru: People think by changing attitudes, their consciousness will change, but it is not . By changing attitudes to certain actions, certain actions will change — yes, positive, beneficial, beneficial. But it\'s not like we are mistaking a plant for the soil. This is something that’s happening everywhere .", \' There is nothing to learn from the past about how to conduct yourself, he says . Change means the residue of the past will still remain. Transformation will not happen. Change will happen. Transformation means nothing . truly transformative. Change is needed today if you want a new generation to have a fresh life .\', \' Consciousness is that dimension, which is the very source of who we are . Our intentions, our actions, our thoughts, and our attitudes are a consequence of that . We are trying to fix the consequences without fixing the source . But you don’t have to learn how to be a life from the past, because past has nothing to do with this. This i
# ...
